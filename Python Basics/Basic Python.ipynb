# %%
print("Hello World")
# Out:
# Hello World

# %%
a=5
b=10.5
c="Ctg"
d=True
e=4+5j

# %%
print(e,a,b,d)
# Out:
# (4+5j) 5 10.5 True

# %%
d=list(map(int,input("Enter Value:").split()))

print(d[0])
# Out:
# Enter Value:3 4 5 6 7 8
# 3

# %%
d=list(input("Enter Fruits:").split())

print(d[2])
# Out:
# Enter Fruits:orange mango lichi papaya tea banana
# lichi

# %%
print(d[5])
# Out:
# 8

# %%
a,b,c=map(int,input("Enter Value:").split())
if a>b and a>c:
  print(f"Max is : {a}")
elif b>a and b>c:
  print(f"Max is : {b}")
else:
  print(f"Max is : {c}")
# Out:
# Enter Value:50 60 89
# Max is : 89
