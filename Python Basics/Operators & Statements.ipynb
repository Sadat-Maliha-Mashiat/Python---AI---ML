# %%
a=5
b=5.5
c="EDU"
d=4+7j
e=True
f=[1,2,3,4]
g=(1,2,3,4,5)
h={1,2,3,4,5}
dc={'A':1,'B':2,'C':3}

# %%
print(f)
# Out:
# [1, 2, 3, 4]

# %%
a,b,c=map(int,input("Enter Values:").split())
# Out:
# Enter Values:1 2 3

# %%
print(a)
# Out:
# 1

# %%
d=list(map(int,input("Enter Values:").split()))
# Out:
# Enter Values:1 2 3 4 5 6 7

# %%
d=set(map(int,input("Enter Values:").split()))
# Out:
# Enter Values:1 2 3 4 5 1 2

# %%
print(d)
# Out:
# {1, 2, 3, 4, 5}

# %%
a,b=5,2

# %%
print(a//b)
# Out:
# 2

# %%
a=int(input("Enter the Number:"))
result="Even" if(a%2==0) else "ODD"
print(result)
# Out:
# Enter the Number:5
# ODD

# %%
a,b=map(int,input("Enter Two Numbers:").split())
op=input("Enter Operator:")

if op=='+':
  print(a+b)
elif op==''

# %% [markdown]
# # Vowel Checker

# %%
vowel="aeiou"
ch=input("Enter Character:")
if ch in vowel:
  print("Vowel")
else:
  print("Consonant")
# Out:
# Enter Character:r
# Consonant
